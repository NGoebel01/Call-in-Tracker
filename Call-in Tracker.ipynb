# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# import and clean the data
df = pd.read_excel('./Mold Call Log - backup 10.6.22.xlsx', sheet_name='Stats', skiprows=6)
df = df.drop(['Unnamed: 2', 'Unnamed: 4'], axis=1)
df = df.drop([12, 13])
df = df.rename(columns={'Calls per Month': 'Month', 'Unnamed: 1': '2021', 'Unnamed: 3': '2022'})
df = df.set_index('Month', drop=True)
df['2021'] = df['2021'].astype('int')
df['2022'] = df['2022'].astype('int')
df
# Out:
#            2021  2022
# Month
# January       0    30
# February      0    18
# March        18    25
# April        16    20
# May          15    17
# June         18    13
# July         25    22
# August       28    36
# September    42    28
# October      30     0
# November     29     0
# December      1     0

# %%
# plotting
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(1, 1, figsize=(10,6))

months = df.index
x_indexes = np.arange(len(months))
width = 0.3

# plot for 2021
y2021 = df['2021']
ax.bar(x_indexes - .15, y2021, width=width, color='#008fd5', label='2021')

# plot for 2022
y2022 = df['2022']
ax.bar(x_indexes + .15, y2022, width=width, color='#444444', label='2022')

ax.set_xticks(ticks=x_indexes, labels=months, rotation=60)

plt.legend()
plt.title('Call-ins per Month')
plt.xlabel('Months')
plt.ylabel('Calls')

plt.tight_layout()
plt.show()
